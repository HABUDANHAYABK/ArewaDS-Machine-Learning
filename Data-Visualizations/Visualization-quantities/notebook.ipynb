# %% [markdown]
# # VISUALIZATION OF QUANTITIES
#
# ## `Data Visualization`
#
# > The most powerfull tools for Data Scientist is the ability to visualize data and craft meaning insight from it. A well crafted graph or plot can ease to draw a conclusion from the `Data`

# %% [markdown]
# ### `Bar Chart`
# A bar-chart is a plot use to visualize categorical data. With `matplotlib` library all the visualizations are made easier.

# %%
import matplotlib.pyplot as plt

nations = ["Nigeria", "Niger", "Chadi", "Ghana"]
pop = [200, 50, 31, 61]

#customize color
color_label = {
    "Nigeria": "green",
    "Niger": "blue",
    "Chadi": "red",
    "Ghana": "black"
}
colors = [color_label[country] for country in nations]
plt.figure(figsize=(8, 4))

plt.bar(nations, pop, color= colors)
plt.title("Some African Countries with their Populations")
plt.xlabel("Countries")
plt.ylabel("Population in millions")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

birds = pd.read_csv(r"c:/users/danhaya/arewads/arewads-fellowship/arewads-machine-learning/data/birds.csv")
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
birds.plot(kind='scatter', x= 'MaxLength', y= 'Order', figsize=((12, 8)))
plt.title("Max Length per Order")
plt.ylabel("Order")
plt.xlabel("Max Length")

plt.show()

# %%
birds['MaxBodyMass'].plot(kind='hist', figsize=((12, 8)))
plt.show()

# %%
birds.plot(kind = 'scatter', x = "Order", y= "MaxLength", figsize=((12, 8)))
plt.title("Maximum Length per Order")
plt.ylabel("Max Length")
plt.xlabel("Order")
plt.xticks(rotation = 90)

plt.show()

# %%
filteredbirds = birds[(birds['MaxBodyMass'] > 1) & (birds["MaxBodyMass"] < 500)]
print(len(birds), len(filteredbirds))

filteredbirds['MaxBodyMass'].plot(kind ='hist', bins = 40, figsize=((12, 8)))
plt.title("Distribution of Body Mass")

plt.show()
# Out:
# 443 319

# %%
x = filteredbirds['MaxBodyMass']
y = filteredbirds['MaxLength']

fig, ax = plt.subplots(tight_layout = True)
hist = ax.hist2d(x, y)

# %%
cs = filteredbirds.ConservationStatus.unique().tolist()
flb = []
for c in cs:
  flb.append(filteredbirds.loc[filteredbirds.ConservationStatus=='{c}', 'MinWingspan'])
# Out:
# [Series([], Name: MinWingspan, dtype: float64), Series([], Name: MinWingspan, dtype: float64), Series([], Name: MinWingspan, dtype: float64), Series([], Name: MinWingspan, dtype: float64), Series([], Name: MinWingspan, dtype: float64), Series([], Name: MinWingspan, dtype: float64)]

# %%
x1 = filteredbirds.loc[filteredbirds.ConservationStatus=='EX', 'MinWingspan']
x2 = filteredbirds.loc[filteredbirds.ConservationStatus=='CR', 'MinWingspan']
x3 = filteredbirds.loc[filteredbirds.ConservationStatus=='EN', 'MinWingspan']
x4 = filteredbirds.loc[filteredbirds.ConservationStatus=='NT', 'MinWingspan']
x5 = filteredbirds.loc[filteredbirds.ConservationStatus=='VU', 'MinWingspan']
x6 = filteredbirds.loc[filteredbirds.ConservationStatus=='LC', 'MinWingspan']

kwargs = dict(alpha=0.5, bins=20)

plt.hist(x1, **kwargs, color='red', label='Extinct')
plt.hist(x2, **kwargs, color='orange', label='Critically Endangered')
plt.hist(x3, **kwargs, color='yellow', label='Endangered')
plt.hist(x4, **kwargs, color='green', label='Near Threatened')
plt.hist(x5, **kwargs, color='blue', label='Vulnerable')
plt.hist(x6, **kwargs, color='gray', label='Least Concern')

plt.gca().set(title='Conservation Status', ylabel='Min Wingspan')
plt.legend();

# %%
birds["ConservationStatus"].unique()
# Out:
# array(['LC', 'NT', 'VU', 'EX', 'EN', 'CR'], dtype=object)

# %%
import seaborn as sns

sns.kdeplot(filteredbirds['MinWingspan'])
plt.show()

# %%
sns.kdeplot(filteredbirds['MaxBodyMass'], bw_adjust=.1)
plt.show()

# %%
sns.kdeplot(filteredbirds['MaxBodyMass'])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
sns.kdeplot(
   data=filteredbirds, x="MaxBodyMass", hue="Order",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
# Out:
# C:\Users\Danhaya\AppData\Local\Temp\ipykernel_10720\4239339279.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# <Axes: xlabel='MaxBodyMass', ylabel='Density'>

# %%
sns.kdeplot(data=filteredbirds, x = 'MinLength', y = 'MaxLength', hue = "ConservationStatus")
plt.show()
# Out:
# C:\Users\Danhaya\AppData\Local\Temp\ipykernel_10720\1197306060.py:1: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=filteredbirds, x = 'MinLength', y = 'MaxLength', hue = "ConservationStatus")
# C:\Users\Danhaya\AppData\Local\Temp\ipykernel_10720\1197306060.py:1: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=filteredbirds, x = 'MinLength', y = 'MaxLength', hue = "ConservationStatus")
# C:\Users\Danhaya\AppData\Local\Temp\ipykernel_10720\1197306060.py:1: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=filteredbirds, x = 'MinLength', y = 'MaxLength', hue = "ConservationStatus")
